# %%
import networkx as nx
import matplotlib.pyplot as plt

# %%
G = nx.graph_atlas(1050)
nx.draw_networkx(G, pos = nx.kamada_kawai_layout(G), arrows= True,  node_size = 800, node_color="orange", style="-.")
